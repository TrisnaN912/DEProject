# %%
import pandas as pd
import psycopg2

# Membaca file CSV
df = pd.read_csv('/data/dfTransjakarta.csv', encoding='latin-1')

# %%
df
# Out:
#               transID            payCardID payCardBank
# 0      EIIW227B8L34VB      180062659848800      emoney  \
# 1      LGXO740D2N47GZ     4885331907664776         dki
# 2      DJWR385V2U57TO     4996225095064169         dki
# 3      JTUZ800U7C86EH         639099174703       flazz
# 4      VMLO535V7F95NJ         570928206772       flazz
# ...               ...                  ...         ...
# 37895  ZWEC949B8Q87QG  4685818286724028395      brizzi
# 37896  YHHK837P6Y95GN     6502902290603767         dki
# 37897  YXPP627N4G95HO      213159426675861      emoney
# 37898  RGVK175U2U98UV      377840859133591      emoney
# 37899  FMZZ963S4B68ZP         501862539795       flazz
#
#                   payCardName payCardSex  payCardBirthDate corridorID
# 0              Bajragin Usada          M              2008          5  \
# 1                Gandi Widodo          F              1997         6C
# 2               Emong Wastuti          F              1992        R1A
# ...

# %%
df = df.drop(['transID', 'payCardID', 'payCardBank', 'payCardName', 'payCardSex', 'payCardBirthDate', 'corridorID', 'direction', 'stopStartSeq', 'stopEndSeq', 'payAmount'], axis=1)

# %%
df
# Out:
#                                    corridorName tapInStops
# 0                         Matraman Baru - Ancol     P00142  \
# 1      Stasiun Tebet - Karet via Patra Kuningan    B01963P
# 2                            Pantai Maju - Kota    B00499P
# 3           Pulo Gebang - Pulo Gadung 2 via PIK    B05587P
# 4                         Tanjung Priok - Pluit     P00239
# ...                                         ...        ...
# 37895         Ragunan - MH Thamrin via Semanggi     P00261
# 37896                    Pinang Ranti - Pramuka     P00064
# 37897                      Cibubur - Balai Kota    B02873P
# 37898               Tanah Abang - Jembatan Lima    B02505P
# 37899                         Ciledug - Tendean     P00001
#
#                tapInStopsName  tapInStopsLat  tapInStopsLon
# 0                   Pal Putih      -6.184631      106.84402  \
# 1                  Kemenkes 2      -6.228700      106.83302
# 2                Gg. Kunir II      -6.133132      106.81435
# ...

# %%
dataframe.isna().sum()
# Out:
# payCardSex             0
# payCardBirthDate       0
# corridorID          1257
# corridorName        1930
# direction              0
# tapInStops          1213
# tapInStopsName         0
# tapInStopsLat          0
# tapInStopsLon          0
# stopStartSeq           0
# tapInTime              0
# tapOutStops         2289
# tapOutStopsName     1344
# tapOutStopsLat      1344
# tapOutStopsLon      1344
# stopEndSeq          1344
# tapOutTime          1344
# payAmount           1007
# dtype: int64

# %%
dataframe.duplicated().sum()
# dataframe.drop_duplicates(inplace=True)
# Out:
# 0
